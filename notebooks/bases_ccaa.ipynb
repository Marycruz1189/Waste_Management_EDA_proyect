# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the datasets
#
# ##### * I have several databases in excel format
# ##### * xlrd is installed to read xls file
# ##### * openpyxl is installed to read xlsx file

# %%
recoleccion = pd.read_excel("data/recogida_residuos.xls")

# %%
## STEPS TO CLEAN
df.head()

### 1. gets rid of any columns we don't need:
to_drop = []
df.drop(to_drop, inplace=True, axis=1)
df.head()
### 2. Cleaning up data fields
       ## see what datatypes we have:
df.get_dtype_counts() #esto no funciona

# %% [markdown]
# ### Step 3. Have a look at the dataset.

# %%
>>>

# %% [markdown]
# ### Estadísticas sobre recogida y tratamiento de residuos. Residuos urbanos- CCAA

# %%
year = re.search('\((.*?)\)', movie_string).group(1)

# %%
startswith('.')  #esto para buscar que empieza por algo

# %%
recoleccion
# Out:
#    Estadísticas sobre recogida y tratamiento de residuos. Residuos urbanos: Serie 2010-2018  \
# 0                        Recogida de residuos urbanos
# 1                                                 NaN
# 2   Cantidad de residuos urbanos recogidos clasifi...
# 3                                 Unidades: Toneladas
# 4                                                 NaN
# 5
# 6
# 7   10.1.1 Residuos domésticos y similares (domést...
# 8   10.1.2 Residuos domésticos voluminosos mezclad...
# 9                               06 Residuos metálicos
# 10                            07.1 Residuos de vidrio
# 11                    07.2 Residuos de papel y cartón
# 12                         07.4 Residuos de plásticos
# 13                            07.5 Residuos de Madera
# 14                             07.6 Residuos textiles
# 15  08.2 y 08.43 Equipos eléctricos desechados y C...
# 16             08.41 Residuos de pilas y acumuladores
# ...

# %%
# -Eliminar las filas de arriba y abajo que no sirven

recogida_clean = recoleccion.loc[5:24, :]
recogida_clean
# Out:
#    Estadísticas sobre recogida y tratamiento de residuos. Residuos urbanos: Serie 2010-2018  \
# 5
# 6
# 7   10.1.1 Residuos domésticos y similares (domést...
# 8   10.1.2 Residuos domésticos voluminosos mezclad...
# 9                               06 Residuos metálicos
# 10                            07.1 Residuos de vidrio
# 11                    07.2 Residuos de papel y cartón
# 12                         07.4 Residuos de plásticos
# 13                            07.5 Residuos de Madera
# 14                             07.6 Residuos textiles
# 15  08.2 y 08.43 Equipos eléctricos desechados y C...
# 16             08.41 Residuos de pilas y acumuladores
# 17                  09. Residuos animales y vegetales
# 18         10.21 Envases mixtos y embalajes mezclados
# 19                           11 Lodos comunes (secos)
# 20  12 Residuos minerales (incluye residuos de con...
# 21                                           18 Otros
# ...

# %%
recogida_clean.T
# Out:
#                               NaN
# Unnamed: 161                                         NaN
# Unnamed: 162                                         NaN
#
#                                                                              6   \
# Estadísticas sobre recogida y tratamiento de re...
# Unnamed: 1                                                       Total nacional
# Unnamed: 2                                                            Andalucía
# Unnamed: 3                                                               Aragón
# Unnamed: 4                                              Asturias, Principado de
# ...                                                                         ...
# Unnamed: 158                                               Madrid, Comunidad de
# Unnamed: 159                                                  Murcia, Región de
# Unnamed: 160                                        Navarra, Comunidad Foral de
# ...

# %%
recogida_clean
# Out:
#    Estadísticas sobre recogida y tratamiento de residuos. Residuos urbanos: Serie 2010-2018  \
# 5
# 6
# 7   10.1.1 Residuos domésticos y similares (domést...
# 8   10.1.2 Residuos domésticos voluminosos mezclad...
# 9                               06 Residuos metálicos
# 10                            07.1 Residuos de vidrio
# 11                    07.2 Residuos de papel y cartón
# 12                         07.4 Residuos de plásticos
# 13                            07.5 Residuos de Madera
# 14                             07.6 Residuos textiles
# 15  08.2 y 08.43 Equipos eléctricos desechados y C...
# 16             08.41 Residuos de pilas y acumuladores
# 17                  09. Residuos animales y vegetales
# 18         10.21 Envases mixtos y embalajes mezclados
# 19                           11 Lodos comunes (secos)
# 20  12 Residuos minerales (incluye residuos de con...
# 21                                           18 Otros
# ...

# %% [markdown]
# ### Residuos gestionados

# %%
gestionados = pd.read_excel("data/residuos_gestionados.xls")

# %%
gestionados
# Out:
# uos: Serie 2010-2018  \
# 0                               Resultados nacionales
# 1                                                 NaN
# 2   Cantidad de residuos no peligrosos y peligroso...
# 3                                 Unidades: toneladas
# 4                                                 NaN
# 5
# 6
# 7
# 8                                               TOTAL
# 9                            01.1. Disolventes usados
# 10         01.2. Residuos ácidos, alcalinos o salinos
# 11                               01.3. Aceites usados
# 12                 01.4 + 02 + 03.1.Residuos químicos
# 13      03.2. Lodos de efluentes industriales (secos)
# 14  03.3. Lodos y residuos líquidos procedentes de...
# 15               05. Residuos sanitarios y biológicos
# 16                             06. Residuos metálicos
# 17                           07.1. Residuos de vidrio
# 18                   07.2. Residuos de papel y cartón
# 19                           07.3. Residuos de caucho
# ...

# %% [markdown]
# ## PIB

# %%
#se puede leer el excel a partir de una fila que le digamos .header=8

pib = pd.read_excel("data/PIBcorriente_milesdeeuros.xlsx", header=0)

# %%
type(pib[2000][1])
# Out:
# int

# %%
pib
# Out:
#              Comunidad Autónoma       2000       2001       2002       2003  \
# 0                           NaN      Valor      Valor      Valor      Valor
# 1                     ANDALUCÍA   86568676   93709992  100949639  109668109
# 2                        ARAGÓN   20071592   21577543   23368239   24975186
# 3       ASTURIAS, PRINCIPADO DE   14305047   15409649   16299205   17208849
# 4                BALEARS, ILLES   16545333   17870191   18874734   19795906
# 5                      CANARIAS   26048646   28352782   30271685   32396850
# 6                     CANTABRIA    7968169    8618734    9196317    9688157
# 7               CASTILLA Y LEÓN   35717613   38031539   40357850   42842365
# 8          CASTILLA - LA MANCHA   21744122   23641769   25423376   27577840
# 9                      CATALUÑA  122427924  132653412  141546705  151491725
# 10         COMUNITAT VALENCIANA   62717924   68504386   73298081   78134696
# ...

# %%
#PARA HACER EL CAMBIO Y PONERLA EN UNA FILA SE PUEDE HACER UN PIVOT TABLE O UN TRASPONER.drop false no la elimina

# %%
#EDA ANALISIS DE SERIES TEMPORALES

# %%
pib
# Out:
#              Comunidad Autónoma       2000       2001       2002       2003  \
# 0                           NaN      Valor      Valor      Valor      Valor
# 1                     ANDALUCÍA   86568676   93709992  100949639  109668109
# 2                        ARAGÓN   20071592   21577543   23368239   24975186
# 3       ASTURIAS, PRINCIPADO DE   14305047   15409649   16299205   17208849
# 4                BALEARS, ILLES   16545333   17870191   18874734   19795906
# 5                      CANARIAS   26048646   28352782   30271685   32396850
# 6                     CANTABRIA    7968169    8618734    9196317    9688157
# 7               CASTILLA Y LEÓN   35717613   38031539   40357850   42842365
# 8          CASTILLA - LA MANCHA   21744122   23641769   25423376   27577840
# 9                      CATALUÑA  122427924  132653412  141546705  151491725
# 10         COMUNITAT VALENCIANA   62717924   68504386   73298081   78134696
# ...

# %%
#elimino la primera fila que no servia 
pib = pib[1:]

# %%
pib
# Out:
#              Comunidad Autónoma       2000       2001       2002       2003  \
# 1                     ANDALUCÍA   86568676   93709992  100949639  109668109
# 2                        ARAGÓN   20071592   21577543   23368239   24975186
# 3       ASTURIAS, PRINCIPADO DE   14305047   15409649   16299205   17208849
# 4                BALEARS, ILLES   16545333   17870191   18874734   19795906
# 5                      CANARIAS   26048646   28352782   30271685   32396850
# 6                     CANTABRIA    7968169    8618734    9196317    9688157
# 7               CASTILLA Y LEÓN   35717613   38031539   40357850   42842365
# 8          CASTILLA - LA MANCHA   21744122   23641769   25423376   27577840
# 9                      CATALUÑA  122427924  132653412  141546705  151491725
# 10         COMUNITAT VALENCIANA   62717924   68504386   73298081   78134696
# 11                  EXTREMADURA   10750237   11516186   12264844   13121521
# ...

# %%
# GUARDAR LA BASE DE DATOS LIMPIA PARA AGRUPAR UNA NUEVA
pib.to_csv('bd_cleaned_pib.csv', index=False)

# %% [markdown]
# ## POBLACION

# %%
poblacion = pd.read_excel("data/poblacion.xls")

# %%
poblacion
# Out:
#    Cifras oficiales de población resultantes de la revisión del Padrón municipal a 1 de enero  \
# 0                   Resumen por comunidades autónomas
# 1                                                 NaN
# 2   Población por comunidades y ciudades autónomas...
# 3                                  Unidades: Personas
# 4                                                 NaN
# 5
# 6                                                Año
# 7                                               Total
# 8                                        01 Andalucía
# 9                                           02 Aragón
# 10                         03 Asturias, Principado de
# 11                                  04 Balears, Illes
# 12                                        05 Canarias
# 13                                       06 Cantabria
# 14                                 07 Castilla y León
# 15                            08 Castilla - La Mancha
# 16                                        09 Cataluña
# ...

# %%
poblacion.shape
# Out:
# (21, 76)

# %%
## Borro esos datos que no me sirven al principio  
poblacion = poblacion.loc[6:26, :]

# %%
poblacion
# Out:
#    Cifras oficiales de población resultantes de la revisión del Padrón municipal a 1 de enero  \
# 6                                                Año
# 7                                               Total
# 8                                        01 Andalucía
# 9                                           02 Aragón
# 10                         03 Asturias, Principado de
# 11                                  04 Balears, Illes
# 12                                        05 Canarias
# 13                                       06 Cantabria
# 14                                 07 Castilla y León
# 15                            08 Castilla - La Mancha
# 16                                        09 Cataluña
# 17                            10 Comunitat Valenciana
# 18                                     11 Extremadura
# 19                                         12 Galicia
# 20                            13 Madrid, Comunidad de
# 21                               14 Murcia, Región de
# ...

# %%
pob = poblacion[poblacion.columns[::-1]]

# %%
cols = pob.columns.tolist()
cols = cols[-1:] + cols[:-1]

# %%
pob = pob[cols]
pob
# Out:
#    Cifras oficiales de población resultantes de la revisión del Padrón municipal a 1 de enero  \
# 6                                                Año
# 7                                               Total
# 8                                        01 Andalucía
# 9                                           02 Aragón
# 10                         03 Asturias, Principado de
# 11                                  04 Balears, Illes
# 12                                        05 Canarias
# 13                                       06 Cantabria
# 14                                 07 Castilla y León
# 15                            08 Castilla - La Mancha
# 16                                        09 Cataluña
# 17                            10 Comunitat Valenciana
# 18                                     11 Extremadura
# 19                                         12 Galicia
# 20                            13 Madrid, Comunidad de
# 21                               14 Murcia, Región de
# ...

# %%
#Elimine los años que no queria es decir desde el 2000 hasta el 2019, elimino tambien 2020
pob.drop(['Unnamed: 75', 'Unnamed: 74', 'Unnamed: 73', 'Unnamed: 72', 'Unnamed: 1'], axis='columns', inplace=True)

# %%
pd.to_numeric(pob.loc[6:6, :], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-160-dc9417124584> in <module>
# ----> 1 pd.to_numeric(pob.loc[6:6, :], errors='coerce')
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     139         values = np.array([arg], dtype="O")
#     140     elif getattr(arg, "ndim", 1) > 1:
# --> 141         raise TypeError("arg must be a list, tuple, 1-d array, or Series")
#     142     else:
#     143         values = arg
#
# TypeError: arg must be a list, tuple, 1-d array, or Series

# %%
pob
# Out:
#    Cifras oficiales de población resultantes de la revisión del Padrón municipal a 1 de enero  \
# 6                                                Año
# 7                                               Total
# 8                                        01 Andalucía
# 9                                           02 Aragón
# 10                         03 Asturias, Principado de
# 11                                  04 Balears, Illes
# 12                                        05 Canarias
# 13                                       06 Cantabria
# 14                                 07 Castilla y León
# 15                            08 Castilla - La Mancha
# 16                                        09 Cataluña
# 17                            10 Comunitat Valenciana
# 18                                     11 Extremadura
# 19                                         12 Galicia
# 20                            13 Madrid, Comunidad de
# 21                               14 Murcia, Región de
# ...

# %%
pob['Unnamed: 70'].iloc[0].apply(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-122-bdb7e03f8641> in <module>
# ----> 1 row_0 = pob['Unnamed: 70'].iloc[0].apply(int)
#
# AttributeError: 'numpy.float64' object has no attribute 'apply'

# %%
#paso la primera fila a titulo
pob.columns = pob.iloc[0]
pob = pob[1:]

# %%
axis='columns', inplace=True)
drop.(['index'])

# %%
pob.reset_index()
# Out:
# 6   index                            Año       2000.0      2001.0      2002.0  \
# 0       7                           Total  20678407.0  20951328.0  21273805.0
# 1       8                    01 Andalucía   3730640.0   3756774.0   3791011.0
# 2       9                       02 Aragón    603787.0    607071.0    614365.0
# 3      10      03 Asturias, Principado de    560169.0    559432.0    558805.0
# 4      11               04 Balears, Illes    426535.0    441287.0    458619.0
# 5      12                     05 Canarias    861377.0    890817.0    920402.0
# 6      13                    06 Cantabria    272477.0    275639.0    277783.0
# 7      14              07 Castilla y León   1257145.0   1256813.0   1256434.0
# 8      15         08 Castilla - La Mancha    873604.0    881766.0    893051.0
# 9      16                     09 Cataluña   3203371.0   3246029.0   3305411.0
# 10     17         10 Comunitat Valenciana   2100062.0   2136121.0   2190385.0
# ...

# %%
pob1 = pob.iloc[:,0].to_string(header=True, index=False)

# %%
pob.loc[1905:, 'Date of Publication'].head(10)

# %%
#convertir la primera fila en string y ponerla como titulo
pob1 = pob.iloc[:,0].to_string(header=True, index=False)

# %%
pob
# Out:
# 6                             Año       2000.0      2001.0      2002.0  \
# 7                            Total  20678407.0  20951328.0  21273805.0
# 8                     01 Andalucía   3730640.0   3756774.0   3791011.0
# 9                        02 Aragón    603787.0    607071.0    614365.0
# 10      03 Asturias, Principado de    560169.0    559432.0    558805.0
# 11               04 Balears, Illes    426535.0    441287.0    458619.0
# 12                     05 Canarias    861377.0    890817.0    920402.0
# 13                    06 Cantabria    272477.0    275639.0    277783.0
# 14              07 Castilla y León   1257145.0   1256813.0   1256434.0
# 15         08 Castilla - La Mancha    873604.0    881766.0    893051.0
# 16                     09 Cataluña   3203371.0   3246029.0   3305411.0
# 17         10 Comunitat Valenciana   2100062.0   2136121.0   2190385.0
# 18                  11 Extremadura    538276.0    539759.0    539511.0
# ...

# %%
[int(x) for x in pob.iloc[0,:]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-d4e2d8c6ae8a> in <module>
# ----> 1 [int(x) for x in pob.iloc[0,:]]
#
# <ipython-input-99-d4e2d8c6ae8a> in <listcomp>(.0)
# ----> 1 [int(x) for x in pob.iloc[0,:]]
#
# ValueError: invalid literal for int() with base 10: ' '

# %%
print (type(pob['Unnamed: 71'].iat[1]))
# Out:
# <class 'numpy.float64'>

# %%
pob
# Out:
#    Cifras oficiales de población resultantes de la revisión del Padrón municipal a 1 de enero  \
# 6
# 7                                               Total
# 8                                        01 Andalucía
# 9                                           02 Aragón
# 10                         03 Asturias, Principado de
# 11                                  04 Balears, Illes
# 12                                        05 Canarias
# 13                                       06 Cantabria
# 14                                 07 Castilla y León
# 15                            08 Castilla - La Mancha
# 16                                        09 Cataluña
# 17                            10 Comunitat Valenciana
# 18                                     11 Extremadura
# 19                                         12 Galicia
# 20                            13 Madrid, Comunidad de
# 21                               14 Murcia, Región de
# 22                     15 Navarra, Comunidad Foral de
# ...
